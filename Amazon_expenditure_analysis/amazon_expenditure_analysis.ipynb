# %%
import pandas as pd
df=pd.read_csv("amazon-orders.csv")
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    NaN    your_email@gmail.com      04/01/19
# 1                    NaN    your_email@gmail.com      04/01/19
# 2                    NaN    your_email@gmail.com      04/01/19
# 3                    NaN    your_email@gmail.com      04/05/19
# 4                    NaN    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        NaN
# ...

# %%
df.shape
# Out:
# (59, 23)

# %%
#Data Cleaning
#Replace NAN values with zero and make chnages in orifinal data frame
df=df.fillna(0)

# %%
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
#Data Cleaning
#Values of Total charged is string,So can't to mathmatical opertions. 
# Remove $ sign(Series.str.replace()) and convert string to float(astype(float))
df["Total Charged"]=df["Total Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# <ipython-input-20-c4f0119bfdf1>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# ...

# %%
#Total amound of money spent on Amazon
df["Total Charged"].sum()
# Out:
# 1777.7300000000002

# %%
#Average Spend
df["Total Charged"].mean()
# Out:
# 30.131016949152542

# %%
#Max Spend
df["Total Charged"].max()
# Out:
# 210.99

# %%
#Meadian Spend
df["Total Charged"].mean()
# Out:
# 30.131016949152542

# %%
#Tax Paid
df["Tax Charged"]=df["Tax Charged"].str.replace('$','').astype(float)
df.head()
# Out:
# <ipython-input-27-03ce12d3623a>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["Tax Charged"]=df["Tax Charged"].str.replace('$','').astype(float)
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0   04/01/19  112-0000000-0000001             Visa - 0001  Amazon.com
# 1   04/01/19  112-0000000-0000002             Visa - 0001  Amazon.com
# 2   04/01/19  112-0000000-0000003             Visa - 0001  Amazon.com
# 3   04/04/19  112-0000000-0000004             Visa - 0001  Amazon.com
# 4   04/05/19  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# ...

# %%
df["Tax Charged"].sum()
# Out:
# 52.60999999999999

# %%
df["Tax Charged"].sum() / df["Total Charged"].sum()
# Out:
# 0.02959392033660904

# %%
#Analyzing Amazon Spending Over Time
df['Order Date'] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order Date             Order ID Payment Instrument Type     Website  \
# 0 2019-04-01  112-0000000-0000001             Visa - 0001  Amazon.com
# 1 2019-04-01  112-0000000-0000002             Visa - 0001  Amazon.com
# 2 2019-04-01  112-0000000-0000003             Visa - 0001  Amazon.com
# 3 2019-04-04  112-0000000-0000004             Visa - 0001  Amazon.com
# 4 2019-04-05  112-0000000-0000005             Visa - 0001  Amazon.com
#
#    Purchase Order Number Ordering Customer Email Shipment Date  \
# 0                    0.0    your_email@gmail.com      04/01/19
# 1                    0.0    your_email@gmail.com      04/01/19
# 2                    0.0    your_email@gmail.com      04/01/19
# 3                    0.0    your_email@gmail.com      04/05/19
# 4                    0.0    your_email@gmail.com      04/07/19
#
#   Shipping Address Name Shipping Address Street 1  Shipping Address Street 2  \
# 0             Your Name             1 YOUR STREET                        0.0
# ...

# %%
# %matplotlib inline
df.plot.bar(x='Order Date', y='Total Charged', rot=90,figsize=(30,30))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
#Above graph contains multiple entries for same day if there are multiple orders in 1 daya which is incorrect
daily_orders=df.groupby('Order Date').sum()["Total Charged"]
daily_orders.head()
# Out:
# Order Date
# 2019-04-01     63.91
# 2019-04-04    156.12
# 2019-04-05     27.64
# 2019-04-07     40.63
# 2019-04-08     44.99
# Name: Total Charged, dtype: float64

# %%
daily_orders.plot.bar(figsize=(20,10),color='green')
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
import matplotlib.pyplot as plt

daily_orders=df.groupby('Order Date').agg({'Total Charged':'sum','Tax Charged':'sum'})
daily_orders.head()
# Out:
#             Total Charged  Tax Charged
# Order Date
# 2019-04-01          63.91         1.93
# 2019-04-04         156.12         8.14
# 2019-04-05          27.64         0.66
# 2019-04-07          40.63         1.65
# 2019-04-08          44.99         0.00

# %%
daily_orders.plot.bar(figsize=(20,10),color=['red','cyan'])
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
df['year'] = pd.DatetimeIndex(df['Order Date']).year
df['month'] = pd.DatetimeIndex(df['Order Date']).month
daily_orders=df.groupby(['year','month']).agg({'Total Charged':'sum','Tax Charged':'sum'})
# Out:
#    Order Date             Order ID Payment Instrument Type     Website  \
# 0  2019-04-01  112-0000000-0000001             Visa - 0001  Amazon.com
# 1  2019-04-01  112-0000000-0000002             Visa - 0001  Amazon.com
# 2  2019-04-01  112-0000000-0000003             Visa - 0001  Amazon.com
# 3  2019-04-04  112-0000000-0000004             Visa - 0001  Amazon.com
# 4  2019-04-05  112-0000000-0000005             Visa - 0001  Amazon.com
# 5  2019-04-05  112-0000000-0000006             Visa - 0001  Amazon.com
# 6  2019-04-07  112-0000000-0000007             Visa - 0001  Amazon.com
# 7  2019-04-08  112-0000000-0000008             Visa - 0001  Amazon.com
# 8  2019-04-20  112-0000000-0000009             Visa - 0001  Amazon.com
# 9  2019-04-23  112-0000000-0000010             Visa - 0001  Amazon.com
# 10 2019-05-05  112-0000000-0000011             Visa - 0001  Amazon.com
# 11 2019-05-06  112-0000000-0000012             Visa - 0001  Amazon.com
# ...
